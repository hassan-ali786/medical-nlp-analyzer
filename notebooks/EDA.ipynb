# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset load karo
df = pd.read_csv("https://raw.githubusercontent.com/semnan-university-ai/Drug-Review-Dataset/main/drugsComTrain_raw.tsv", sep="\t")

# Save karo data folder mein
df.to_csv("../data/drugsComTrain_raw.csv", index=False)

print(df.shape)
print(df.head())
